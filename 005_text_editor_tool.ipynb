# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Implementation of the TextEditorTool
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            # Create backup before modifying
            self._backup_file(abs_path)

            # Perform the replacement
            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            # Check if file already exists
            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            # Create parent directories if they don't exist
            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            # Create the file
            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            # Create backup before modifying
            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            # Handle line endings
            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            # Insert at the beginning if insert_line is 0
            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            # Insert after the specified line
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))

# %%
# Process Tool Call Requests
import json

text_editor_tool = TextEditorTool()


def run_tool(tool_name, tool_input):
    if tool_name in ("str_replace_editor", "str_replace_based_edit_tool"):
        command = tool_input["command"]
        if command == "view":
            return text_editor_tool.view(
                tool_input["path"], tool_input.get("view_range")
            )
        elif command == "str_replace":
            return text_editor_tool.str_replace(
                tool_input["path"], tool_input["old_str"], tool_input["new_str"]
            )
        elif command == "create":
            return text_editor_tool.create(tool_input["path"], tool_input["file_text"])
        elif command == "insert":
            return text_editor_tool.insert(
                tool_input["path"],
                tool_input["insert_line"],
                tool_input["new_str"],
            )
        elif command == "undo_edit":
            return text_editor_tool.undo_edit(tool_input["path"])
        else:
            raise Exception(f"Unknown text editor command: {command}")
    else:
        raise Exception(f"Unknown tool name: {tool_name}")


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Make the text edit schema based on the model version being used
def get_text_edit_schema(model):
    #return {"type": "text_editor_20250728","name": "str_replace_based_edit_tool",}
    if model.startswith("claude-3-7-sonnet"):
        return {
           "type": "text_editor_20250124",
           "name": "str_replace_editor",
        }
    elif model.startswith("claude-3-5-sonnet"):
        return {
           "type": "text_editor_20241022",
           "name": "str_replace_editor",
        }
    elif model.startswith("claude-sonnet-4-5"):
        return {
            "type": "text_editor_20250728",
            "name": "str_replace_based_edit_tool",
        }
    else:
        raise ValueError(
            f"Editor schema version not known for model: {model}. Reference Anthropic docs for more information."
        )

# %%
# Run the conversation in a loop until the model doesn't ask for a tool use
def run_conversation(messages):
    while True:
        response = chat(
            messages,
            tools=[get_text_edit_schema(model)],
        )

        add_assistant_message(messages, response)
        print(text_from_message(response))

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

    return messages

# %%
messages = []

add_user_message(
    messages,
    """
    Open the ./main.py file and write out a function to calculate pi to the 5th digit.

    Then create a ./test.py file to test your implementation. 
    """,
)

run_conversation(messages)
# Out:
# I'll help you create a function to calculate pi to the 5th digit in main.py and then create a test file for it.
#
# Now I'll add a function to calculate pi to the 5th digit. I'll use the Leibniz formula or a more efficient method like the Machin formula for better convergence.
# Now let's create a test file to verify our implementation:
# Perfect! Let me verify the files were created correctly:
#
# Perfect! I've successfully created both files:
#
# ## Summary
#
# ### **main.py**
# I added a `calculate_pi()` function that:
# - Uses the **Machin formula** for fast convergence: `pi/4 = 4*arctan(1/5) - arctan(1/239)`
# - Implements an `arctan()` helper function using Taylor series expansion
# - Returns pi accurate to at least 5 decimal places (**3.14159**)
#
# ### **test.py**
# Created a comprehensive test suite with three test functions:
# 1. **test_calculate_pi()** - Compares the calculated value against Python's `math.pi` to 5 decimal places
# 2. **test_pi_range()** - Verifies pi is in a reasonable range (3.14 < pi < 3.15)
# 3. **test_pi_first_five_digits()** - Confirms the result is exactly "3.14159" when formatted to 5 decimal places
#
# You can run the test file with:
# ```bash
# python test.py
# ```
#
# The implementation uses the Machin formula which is much more efficient than simpler methods (like the Leibniz formula) and converges quickly to give accurate results for pi.
# [{'role': 'user',
#   'content': '\n    Open the ./main.py file and write out a function to calculate pi to the 5th digit.\n\n    Then create a ./test.py file to test your implementation. \n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll help you create a function to calculate pi to the 5th digit in main.py and then create a test file for it.", type='text'),
#    ToolUseBlock(id='toolu_01RmUatkJ8kYr54HcSxqPA5a', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': '.'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01RmUatkJ8kYr54HcSxqPA5a',
#     'content': '".backups\\n.env\\n.git\\n.gitignore\\n005_text_editor_tool.ipynb\\nLICENSE\\nmain.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_012cAe4oxtZ9RVvhZjeTP3tA', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_012cAe4oxtZ9RVvhZjeTP3tA',
#     'content': '"1: def greeting():\\n2:     print(\\"Hi There\\")"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Now I'll add a function to calculate pi to the 5th digit. I'll use the Leibniz formula or a more efficient method like the Machin formula for better convergence.", type='text'),
#    ToolUseBlock(id='toolu_01BhZF4NGNq3EgFS1drEP46u', caller=DirectCaller(type='direct'), input={'command': 'str_replace', 'path': './main.py', 'old_str': 'def greeting():\n    print("Hi There")', 'new_str': 'def greeting():\n    print("Hi There")\n\n\ndef calculate_pi():\n    """\n    Calculate pi to the 5th decimal digit using the Machin formula.\n    Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\n    \n    This method converges much faster than simpler formulas.\n    Returns pi accurate to at least 5 decimal places (3.14159).\n    """\n    def arctan(x, num_terms=50):\n        """Calculate arctan(x) using Taylor series expansion."""\n        result = 0\n        x_squared = x * x\n        x_power = x\n        \n        for n in range(num_terms):\n            sign = (-1) ** n\n            result += sign * x_power / (2 * n + 1)\n            x_power *= x_squared\n        \n        return result\n    \n    # Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\n    pi = 4 * (4 * arctan(1/5) - arctan(1/239))\n    \n    return pi'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01BhZF4NGNq3EgFS1drEP46u',
#     'content': '"Successfully replaced text at exactly one location."',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Now let's create a test file to verify our implementation:", type='text'),
#    ToolUseBlock(id='toolu_01EoQ6oovBCMk6YBw3c1nmeh', caller=DirectCaller(type='direct'), input={'command': 'create', 'path': './test.py', 'file_text': 'import math\nfrom main import calculate_pi\n\n\ndef test_calculate_pi():\n    """Test that calculate_pi returns pi accurate to 5 decimal places."""\n    calculated_pi = calculate_pi()\n    actual_pi = math.pi\n    \n    # Test accuracy to 5 decimal places (3.14159)\n    print(f"Calculated pi: {calculated_pi}")\n    print(f"Math.pi value: {actual_pi}")\n    print(f"Difference: {abs(calculated_pi - actual_pi)}")\n    \n    # Round both to 5 decimal places and compare\n    calculated_rounded = round(calculated_pi, 5)\n    actual_rounded = round(actual_pi, 5)\n    \n    print(f"\\nCalculated pi (5 decimals): {calculated_rounded}")\n    print(f"Actual pi (5 decimals): {actual_rounded}")\n    \n    assert calculated_rounded == actual_rounded, \\\n        f"Pi calculation not accurate to 5 decimal places. Got {calculated_rounded}, expected {actual_rounded}"\n    \n    # Also verify the value is close to expected 3.14159\n    assert abs(calculated_pi - 3.14159) < 0.000001, \\\n        f"Pi should be approximately 3.14159, got {calculated_pi}"\n    \n    print("\\n✓ All tests passed! Pi calculated correctly to 5 decimal places.")\n\n\ndef test_pi_range():\n    """Test that calculated pi is in a reasonable range."""\n    calculated_pi = calculate_pi()\n    \n    assert 3.14 < calculated_pi < 3.15, \\\n        f"Pi should be between 3.14 and 3.15, got {calculated_pi}"\n    \n    print("✓ Pi is in the expected range.")\n\n\ndef test_pi_first_five_digits():\n    """Test that the first 5 decimal digits are correct (3.14159)."""\n    calculated_pi = calculate_pi()\n    \n    # Extract first 5 decimal digits\n    pi_string = f"{calculated_pi:.5f}"\n    \n    print(f"Pi to 5 decimal places: {pi_string}")\n    \n    assert pi_string == "3.14159", \\\n        f"Expected \'3.14159\', got \'{pi_string}\'"\n    \n    print("✓ First 5 decimal digits are correct: 3.14159")\n\n\nif __name__ == "__main__":\n    print("Running tests for calculate_pi()...\\n")\n    print("=" * 60)\n    \n    try:\n        test_calculate_pi()\n        print("\\n" + "=" * 60)\n        test_pi_range()\n        print("\\n" + "=" * 60)\n        test_pi_first_five_digits()\n        print("\\n" + "=" * 60)\n        print("\\n🎉 All tests passed successfully!")\n    except AssertionError as e:\n        print(f"\\n❌ Test failed: {e}")\n    except Exception as e:\n        print(f"\\n❌ Unexpected error: {e}")\n'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01EoQ6oovBCMk6YBw3c1nmeh',
#     'content': '"Successfully created ./test.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Perfect! Let me verify the files were created correctly:', type='text'),
#    ToolUseBlock(id='toolu_01DkzDNCQuUurboCx9153fU8', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01DkzDNCQuUurboCx9153fU8',
#     'content': '"1: def greeting():\\n2:     print(\\"Hi There\\")\\n3: \\n4: \\n5: def calculate_pi():\\n6:     \\"\\"\\"\\n7:     Calculate pi to the 5th decimal digit using the Machin formula.\\n8:     Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n9:     \\n10:     This method converges much faster than simpler formulas.\\n11:     Returns pi accurate to at least 5 decimal places (3.14159).\\n12:     \\"\\"\\"\\n13:     def arctan(x, num_terms=50):\\n14:         \\"\\"\\"Calculate arctan(x) using Taylor series expansion.\\"\\"\\"\\n15:         result = 0\\n16:         x_squared = x * x\\n17:         x_power = x\\n18:         \\n19:         for n in range(num_terms):\\n20:             sign = (-1) ** n\\n21:             result += sign * x_power / (2 * n + 1)\\n22:             x_power *= x_squared\\n23:         \\n24:         return result\\n25:     \\n26:     # Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n27:     pi = 4 * (4 * arctan(1/5) - arctan(1/239))\\n28:     \\n29:     return pi"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_01MsAYR7wbHFxwrcP1wRZDor', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './test.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01MsAYR7wbHFxwrcP1wRZDor',
#     'content': '"1: import math\\n2: from main import calculate_pi\\n3: \\n4: \\n5: def test_calculate_pi():\\n6:     \\"\\"\\"Test that calculate_pi returns pi accurate to 5 decimal places.\\"\\"\\"\\n7:     calculated_pi = calculate_pi()\\n8:     actual_pi = math.pi\\n9:     \\n10:     # Test accuracy to 5 decimal places (3.14159)\\n11:     print(f\\"Calculated pi: {calculated_pi}\\")\\n12:     print(f\\"Math.pi value: {actual_pi}\\")\\n13:     print(f\\"Difference: {abs(calculated_pi - actual_pi)}\\")\\n14:     \\n15:     # Round both to 5 decimal places and compare\\n16:     calculated_rounded = round(calculated_pi, 5)\\n17:     actual_rounded = round(actual_pi, 5)\\n18:     \\n19:     print(f\\"\\\\nCalculated pi (5 decimals): {calculated_rounded}\\")\\n20:     print(f\\"Actual pi (5 decimals): {actual_rounded}\\")\\n21:     \\n22:     assert calculated_rounded == actual_rounded, \\\\\\n23:         f\\"Pi calculation not accurate to 5 decimal places. Got {calculated_rounded}, expected {actual_rounded}\\"\\n24:     \\n25:     # Also verify the value is close to expected 3.14159\\n26:     assert abs(calculated_pi - 3.14159) < 0.000001, \\\\\\n27:         f\\"Pi should be approximately 3.14159, got {calculated_pi}\\"\\n28:     \\n29:     print(\\"\\\\n\\u2713 All tests passed! Pi calculated correctly to 5 decimal places.\\")\\n30: \\n31: \\n32: def test_pi_range():\\n33:     \\"\\"\\"Test that calculated pi is in a reasonable range.\\"\\"\\"\\n34:     calculated_pi = calculate_pi()\\n35:     \\n36:     assert 3.14 < calculated_pi < 3.15, \\\\\\n37:         f\\"Pi should be between 3.14 and 3.15, got {calculated_pi}\\"\\n38:     \\n39:     print(\\"\\u2713 Pi is in the expected range.\\")\\n40: \\n41: \\n42: def test_pi_first_five_digits():\\n43:     \\"\\"\\"Test that the first 5 decimal digits are correct (3.14159).\\"\\"\\"\\n44:     calculated_pi = calculate_pi()\\n45:     \\n46:     # Extract first 5 decimal digits\\n47:     pi_string = f\\"{calculated_pi:.5f}\\"\\n48:     \\n49:     print(f\\"Pi to 5 decimal places: {pi_string}\\")\\n50:     \\n51:     assert pi_string == \\"3.14159\\", \\\\\\n52:         f\\"Expected \'3.14159\', got \'{pi_string}\'\\"\\n53:     \\n54:     print(\\"\\u2713 First 5 decimal digits are correct: 3.14159\\")\\n55: \\n56: \\n57: if __name__ == \\"__main__\\":\\n58:     print(\\"Running tests for calculate_pi()...\\\\n\\")\\n59:     print(\\"=\\" * 60)\\n60:     \\n61:     try:\\n62:         test_calculate_pi()\\n63:         print(\\"\\\\n\\" + \\"=\\" * 60)\\n64:         test_pi_range()\\n65:         print(\\"\\\\n\\" + \\"=\\" * 60)\\n66:         test_pi_first_five_digits()\\n67:         print(\\"\\\\n\\" + \\"=\\" * 60)\\n68:         print(\\"\\\\n\\ud83c\\udf89 All tests passed successfully!\\")\\n69:     except AssertionError as e:\\n70:         print(f\\"\\\\n\\u274c Test failed: {e}\\")\\n71:     except Exception as e:\\n72:         print(f\\"\\\\n\\u274c Unexpected error: {e}\\")\\n73: "',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Perfect! I\'ve successfully created both files:\n\n## Summary\n\n### **main.py**\nI added a `calculate_pi()` function that:\n- Uses the **Machin formula** for fast convergence: `pi/4 = 4*arctan(1/5) - arctan(1/239)`\n- Implements an `arctan()` helper function using Taylor series expansion\n- Returns pi accurate to at least 5 decimal places (**3.14159**)\n\n### **test.py**\nCreated a comprehensive test suite with three test functions:\n1. **test_calculate_pi()** - Compares the calculated value against Python\'s `math.pi` to 5 decimal places\n2. **test_pi_range()** - Verifies pi is in a reasonable range (3.14 < pi < 3.15)\n3. **test_pi_first_five_digits()** - Confirms the result is exactly "3.14159" when formatted to 5 decimal places\n\nYou can run the test file with:\n```bash\npython test.py\n```\n\nThe implementation uses the Machin formula which is much more efficient than simpler methods (like the Leibniz formula) and converges quickly to give accurate results for pi.', type='text')]}]
